# %%
#libraries for data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#patient encounters
df_patient = pd.read_csv("../data/raw/patient_encounters_2023.csv")

# %%
#shape
df_patient.shape
# Out:
# (101766, 50)

# %%
#dtypes for each column
df_patient.dtypes
# Out:
# encounter_id                int64
# patient_nbr                 int64
# race                          str
# gender                        str
# age                           str
# weight                        str
# admission_type_id           int64
# discharge_disposition_id    int64
# admission_source_id         int64
# time_in_hospital            int64
# payer_code                    str
# medical_specialty             str
# num_lab_procedures          int64
# num_procedures              int64
# num_medications             int64
# number_outpatient           int64
# number_emergency            int64
# number_inpatient            int64
# diag_1                        str
# diag_2                        str
# diag_3                        str
# number_diagnoses            int64
# max_glu_serum                 str
# A1Cresult                     str
# metformin                     str
# repaglinide                   str
# nateglinide                   str
# chlorpropamide                str
# glimepiride                   str
# acetohexamide                 str
# glipizide                     str
# glyburide                     str
# tolbutamide                   str
# pioglitazone                  str
# rosiglitazone                 str
# acarbose                      str
# miglitol                      str
# troglitazone                  str
# tolazamide                    str
# examide                       str
# citoglipton                   str
# insulin                       str
# glyburide-metformin           str
# glipizide-metformin           str
# glimepiride-pioglitazone      str
# metformin-rosiglitazone       str
# metformin-pioglitazone        str
# change                        str
# diabetesMed                   str
# readmitted                    str
# dtype: object

# %%
#start of preprocessing.py help for patient encounters

# %%
#1 convert and print all null values



# Replace '?' with NaN across the entire dataframe
df_patient.replace('?', np.nan, inplace=True)

    # These columns should be numeric but may have loaded as strings
numeric_cols = ['weight', 'payer_code', 'medical_specialty']
    # Be careful: not all of these are truly numeric (medical_specialty is categorical)

df_patient.isnull().sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         2273
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum               96420
# A1Cresult                   84748
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# examide                         0
# citoglipton                     0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# dtype: int64

# %%
#2 Understanding What's Missing and Why
"""
    Missing data in healthcare is rarely random.

    In this dataset:
    - weight (97% missing): Only recorded for specific admission types
    - medical_specialty (49% missing): Not always documented in ER admissions
    - payer_code (40% missing): Insurance info sometimes unavailable
    - max_glu_serum (95% missing): Only ordered when clinically indicated
    - A1Cresult (83% missing): Only ordered when clinically indicated

    The MISSINGNESS ITSELF can be a feature. A missing glucose test might mean
    the clinician didn't think it was necessary — that's clinical information.
"""
missing = pd.DataFrame({
    'column': df_patient.columns,
    'missing_count': df_patient.isnull().sum().values,
    'missing_pct': (df_patient.isnull().sum().values / len(df_patient) * 100).round(1)
})

missing = missing.sort_values('missing_pct', ascending=False)

print(missing)
# Out:
#                       column  missing_count  missing_pct
# 5                     weight          98569         96.9
# 22             max_glu_serum          96420         94.7
# 23                 A1Cresult          84748         83.3
# 11         medical_specialty          49949         49.1
# 10                payer_code          40256         39.6
# 2                       race           2273          2.2
# 20                    diag_3           1423          1.4
# 19                    diag_2            358          0.4
# 1                patient_nbr              0          0.0
# 0               encounter_id              0          0.0
# 9           time_in_hospital              0          0.0
# 8        admission_source_id              0          0.0
# 12        num_lab_procedures              0          0.0
# 13            num_procedures              0          0.0
# 6          admission_type_id              0          0.0
# 7   discharge_disposition_id              0          0.0
# 3                     gender              0          0.0
# 4                        age              0          0.0
# 17          number_inpatient              0          0.0
# 16          number_emergency              0          0.0
# 15         number_outpatient              0          0.0
# 14           num_medications              0          0.0
# 21          number_diagnoses              0          0.0
# 18                    diag_1             21          0.0
# 24                 metformin              0          0.0
# 25               repaglinide              0          0.0
# 26               nateglinide              0          0.0
# 27            chlorpropamide              0          0.0
# 28               glimepiride              0          0.0
# 29             acetohexamide              0          0.0
# 30                 glipizide              0          0.0
# 31                 glyburide              0          0.0
# 32               tolbutamide              0          0.0
# 33              pioglitazone              0          0.0
# 34             rosiglitazone              0          0.0
# 35                  acarbose              0          0.0
# 36                  miglitol              0          0.0
# 37              troglitazone              0          0.0
# 38                tolazamide              0          0.0
# 39                   examide              0          0.0
# 40               citoglipton              0          0.0
# 41                   insulin              0          0.0
# 42       glyburide-metformin              0          0.0
# 43       glipizide-metformin              0          0.0
# 44  glimepiride-pioglitazone              0          0.0
# 45   metformin-rosiglitazone              0          0.0
# 46    metformin-pioglitazone              0          0.0
# 47                    change              0          0.0
# 48               diabetesMed              0          0.0
# 49                readmitted              0          0.0

# %%
#3 age encoding
age_map = {
    '[0-10)': 5, '[10-20)': 15, '[20-30)': 25,
    '[30-40)': 35, '[40-50)': 45, '[50-60)': 55,
    '[60-70)': 65, '[70-80)': 75, '[80-90)': 85,
    '[90-100)': 95
}

df_patient['age_numeric'] = df_patient['age'].map(age_map)

print(df_patient['age_numeric'])
# Out:
# 0          5
# 1         15
# 2         25
# 3         35
# 4         45
#           ..
# 101761    75
# 101762    85
# 101763    75
# 101764    85
# 101765    75
# Name: age_numeric, Length: 101766, dtype: int64

# %%
#4: ICD-9 Diagnostic Codes
diag_cols = ['diag_1', 'diag_2', 'diag_3']

for col in diag_cols:
    # Clean to string for safe checks
    code_str = df_patient[col].astype(str).str.strip()

    # Pull first 3 numeric digits when present
    code_num = pd.to_numeric(
        code_str.str.extract(r'^(\d{3})')[0],
        errors='coerce'
    )  

    # Build category column
    df_patient[col + '_category'] = np.select(
        [
            df_patient[col].isna(),                         # missing
            code_str.str.startswith('250'),                # diabetes
            code_num.between(390, 459),                    # circulatory
            code_num.between(460, 519),                    # respiratory
            code_num.between(520, 579),                    # digestive
            code_str.str.startswith(('V', 'E'))            # external
        ],
        [
            'missing',
            'diabetes',
            'circulatory',
            'respiratory',
            'digestive',
            'external'
        ],
        default='other'
    )

# check results
df_patient[['diag_1', 'diag_1_category', 'diag_2', 'diag_2_category', 'diag_3', 'diag_3_category']].head()
# Out:
#    diag_1 diag_1_category  diag_2 diag_2_category diag_3 diag_3_category
# 0  250.83        diabetes     NaN         missing    NaN         missing
# 1     276           other  250.01        diabetes    255           other
# 2     648           other     250        diabetes    V27        external
# 3       8           other  250.43        diabetes    403     circulatory
# 4     197           other     157           other    250        diabetes

# %%
#5a Creating the Readmission Target — BINARY
# Create binary target: 1 = readmitted (<30 or >30), 0 = not readmitted (NO)
df_patient['readmission_binary'] = (df_patient['readmitted'] != 'NO').astype(int)

# Quick distribution check
pos = df_patient['readmission_binary'].sum()
neg = len(df_patient) - pos

print("Readmission binary target created:")
print(f"  Readmitted (1): {pos} ({pos/len(df_patient)*100:.1f}%)")
print(f"  Not readmitted (0): {neg} ({neg/len(df_patient)*100:.1f}%)")

# Optional: quick sanity check
df_patient[['readmitted', 'readmission_binary']].head()
# Out:
# Readmission binary target created:
#   Readmitted (1): 46902 (46.1%)
#   Not readmitted (0): 54864 (53.9%)
#   readmitted  readmission_binary
# 0         NO                   0
# 1        >30                   1
# 2         NO                   0
# 3         NO                   0
# 4         NO                   0

# %%
#5b Exclude Death/Hospice Discharges (CRITICAL)

"""
    CRITICAL: Exclude patients who died or were discharged to hospice.
    These patients cannot be "readmitted" — including them creates data leakage
    because their outcome is guaranteed to be "no readmission" for reasons
    unrelated to clinical care quality.

    Discharge disposition IDs to exclude:
      11 = Expired
      13 = Hospice / home
      14 = Hospice / medical facility
      19 = Expired at home (Medicaid only, hospice)
      20 = Expired in a medical facility (Medicaid only, hospice)
      21 = Expired, place unknown (Medicaid only, hospice)

    Run this BEFORE creating your readmission target variable.
"""
exclude_dispositions = [11, 13, 14, 19, 20, 21]

n_before = len(df_patient)

df_patient = df_patient[
    ~df_patient['discharge_disposition_id'].isin(exclude_dispositions)
]

n_after = len(df_patient)

print(f"Excluded {n_before - n_after} death/hospice rows ({n_before} -> {n_after})")

# Optional sanity check
df_patient['discharge_disposition_id'].value_counts().head()
# Out:
# Excluded 2423 death/hospice rows (101766 -> 99343)
# discharge_disposition_id
# 1     60234
# 3     13954
# 6     12902
# 18     3691
# 2      2128
# Name: count, dtype: int64

# %%
#6: Medication Feature Engineering
med_cols = [
    'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
    'glimepiride', 'acetohexamide', 'glipizide', 'glyburide',
    'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose',
    'miglitol', 'troglitazone', 'tolazamide', 'insulin',
    'glyburide-metformin', 'glipizide-metformin',
    'glimepiride-pioglitazone', 'metformin-rosiglitazone',
    'metformin-pioglitazone'
]

# Only keep medication columns that actually exist
med_cols = [c for c in med_cols if c in df_patient.columns]

# Count medications that changed (anything not "No")
df_patient['n_meds_changed'] = df_patient[med_cols].apply(
    lambda row: sum(1 for v in row if v != 'No'),
    axis=1
)

# Binary flag: any medication changed
df_patient['any_med_changed'] = (df_patient['n_meds_changed'] > 0).astype(int)

# Count medications increased
df_patient['n_meds_increased'] = df_patient[med_cols].apply(
    lambda row: sum(1 for v in row if v == 'Up'),
    axis=1
)

# Optional check
df_patient[['n_meds_changed', 'any_med_changed', 'n_meds_increased']].head()
# Out:
#    n_meds_changed  any_med_changed  n_meds_increased
# 0               0                0                 0
# 1               1                1                 1
# 2               1                1                 0
# 3               1                1                 1
# 4               2                1                 0

# %%
#7 Clinical Complexity Score
df_patient['complexity_score'] = (
    df_patient['num_lab_procedures'].fillna(0) / 50 +
    df_patient['num_procedures'].fillna(0) / 6 +
    df_patient['num_medications'].fillna(0) / 20 +
    df_patient['number_diagnoses'].fillna(0) / 9 + 
    df_patient['number_emergency'].fillna(0) / 3 +
    df_patient['number_inpatient'].fillna(0) / 5
)

# Optional check
df_patient[['complexity_score']].head()
# Out:
#    complexity_score
# 0          0.981111
# 1          3.080000
# 2          2.570000
# 3          2.624444
# 4          1.975556

# %%
#target variable distribution/class imbalance
for col in df_patient.columns:
    print(f"\nColumn: {col}")
    print(df_patient[col].value_counts(normalize=True) * 100)
# Out:
# Column: encounter_id
# encounter_id
# 2278392      0.001007
# 149190       0.001007
# 64410        0.001007
# 500364       0.001007
# 16680        0.001007
#                ...
# 443847548    0.001007
# 443847782    0.001007
# 443854148    0.001007
# 443857166    0.001007
# 443867222    0.001007
# Name: proportion, Length: 99343, dtype: float64
#
# Column: patient_nbr
# patient_nbr
# 88785891     0.040265
# 43140906     0.028185
# 1660293      0.023152
# 23199021     0.023152
# 88227540     0.023152
#                ...
# 183087545    0.001007
# 188574944    0.001007
# 140199494    0.001007
# 120975314    0.001007
# 175429310    0.001007
# Name: proportion, Length: 69990, dtype: float64
#
# Column: race
# race
# Caucasian          76.429579
# AfricanAmerican    19.330855
# Hispanic            2.077047
# Other               1.515822
# Asian               0.646696
# Name: proportion, dtype: float64
#
# Column: gender
# gender
# Female             53.807515
# Male               46.189465
# Unknown/Invalid     0.003020
# Name: proportion, dtype: float64
#
# Column: age
# age
# [70-80)     25.498525
# [60-70)     22.204886
# [50-60)     17.172825
# [80-90)     16.542685
# [40-50)      9.670535
# [30-40)      3.788893
# [90-100)     2.606122
# [20-30)      1.659906
# [10-20)      0.694563
# [0-10)       0.161058
# Name: proportion, dtype: float64
#
# Column: weight
# weight
# [75-100)     41.984
# [50-75)      27.744
# [100-125)    19.744
# [125-150)     4.576
# [25-50)       2.880
# [0-25)        1.536
# [150-175)     1.088
# [175-200)     0.352
# >200          0.096
# Name: proportion, dtype: float64
#
# Column: admission_type_id
# admission_type_id
# 1    52.717353
# 3    18.791460
# 2    18.251915
# 6     5.241436
# 5     4.647534
# 8     0.322116
# 7     0.018119
# 4     0.010066
# Name: proportion, dtype: float64
#
# Column: discharge_disposition_id
# discharge_disposition_id
# 1     60.632355
# 3     14.046284
# 6     12.987327
# 18     3.715410
# 2      2.142073
# 22     2.006181
# 5      1.191830
# 25     0.995541
# 4      0.820390
# 7      0.627120
# 23     0.414725
# 28     0.139919
# 8      0.108714
# 15     0.063417
# 24     0.048317
# 9      0.021139
# 17     0.014093
# 16     0.011073
# 10     0.006040
# 27     0.005033
# 12     0.003020
# Name: proportion, dtype: float64
#
# Column: admission_source_id
# admission_source_id
# 7     56.219361
# 1     29.360901
# 17     6.613450
# 4      3.138621
# 6      2.253808
# 2      1.088149
# 5      0.811330
# 3      0.186223
# 20     0.160052
# 9      0.125827
# 8      0.015099
# 22     0.012079
# 10     0.008053
# 14     0.002013
# 11     0.002013
# 25     0.002013
# 13     0.001007
# Name: proportion, dtype: float64
#
# Column: time_in_hospital
# time_in_hospital
# 3     17.547286
# 2     17.002708
# 1     13.915424
# 4     13.774498
# 5      9.813475
# 6      7.403642
# 7      5.733670
# 8      4.299246
# 9      2.898040
# 10     2.276960
# 11     1.781706
# 12     1.392146
# 13     1.159619
# 14     1.001580
# Name: proportion, dtype: float64
#
# Column: payer_code
# payer_code
# MC    52.269580
# HM    10.334473
# SP     8.242556
# BC     7.675369
# MD     5.793644
# CP     4.113771
# UN     4.022020
# CM     3.136208
# OG     1.686546
# PO     0.975895
# DM     0.909167
# CH     0.236884
# WC     0.225206
# OT     0.153474
# MP     0.131787
# SI     0.091751
# FR     0.001668
# Name: proportion, dtype: float64
#
# Column: medical_specialty
# medical_specialty
# InternalMedicine          28.065922
# Emergency/Trauma          14.625347
# Family/GeneralPractice    14.296134
# Cardiology                10.406687
# Surgery-General            6.030319
#                             ...
# Dermatology                0.001971
# SportsMedicine             0.001971
# Speech                     0.001971
# Perinatology               0.001971
# Neurophysiology            0.001971
# Name: proportion, Length: 72, dtype: float64
#
# Column: num_lab_procedures
# num_lab_procedures
# 1      3.173852
# 43     2.770200
# 44     2.463183
# 45     2.346416
# 38     2.194417
#          ...
# 120    0.001007
# 132    0.001007
# 121    0.001007
# 126    0.001007
# 118    0.001007
# Name: proportion, Length: 118, dtype: float64
#
# Column: num_procedures
# num_procedures
# 0    45.981096
# 1    20.383922
# 2    12.454828
# 3     9.263864
# 6     4.832751
# 4     4.075778
# 5     3.007761
# Name: proportion, dtype: float64
#
# Column: num_medications
# num_medications
# 13    6.015522
# 12    5.926940
# 11    5.733670
# 15    5.731657
# 14    5.628982
#         ...
# 70    0.002013
# 75    0.002013
# 81    0.001007
# 79    0.001007
# 74    0.001007
# Name: proportion, Length: 75, dtype: float64
#
# Column: number_outpatient
# number_outpatient
# 0     83.542877
# 1      8.404216
# 2      3.532207
# 3      2.010207
# 4      1.084123
# 5      0.517399
# 6      0.295944
# 7      0.155018
# 8      0.096635
# 9      0.082542
# 10     0.057377
# 11     0.041271
# 13     0.030198
# 12     0.029192
# 14     0.028185
# 15     0.020132
# 16     0.013086
# 17     0.008053
# 20     0.006040
# 21     0.006040
# 18     0.005033
# 22     0.005033
# 19     0.003020
# 27     0.003020
# 24     0.003020
# 35     0.002013
# 29     0.002013
# 36     0.002013
# 26     0.002013
# 33     0.002013
# 23     0.002013
# 42     0.001007
# 39     0.001007
# 34     0.001007
# 25     0.001007
# 28     0.001007
# 37     0.001007
# 38     0.001007
# 40     0.001007
# Name: proportion, dtype: float64
#
# Column: number_emergency
# number_emergency
# 0     88.832630
# 1      7.523429
# 2      1.997121
# 3      0.710669
# 4      0.371440
# 5      0.191257
# 6      0.093615
# 7      0.072476
# 8      0.050331
# 10     0.034225
# 9      0.033218
# 11     0.023152
# 13     0.012079
# 12     0.010066
# 22     0.006040
# 16     0.005033
# 18     0.005033
# 20     0.004026
# 19     0.004026
# 15     0.003020
# 14     0.003020
# 25     0.002013
# 21     0.002013
# 42     0.001007
# 28     0.001007
# 46     0.001007
# 76     0.001007
# 37     0.001007
# 64     0.001007
# 63     0.001007
# 54     0.001007
# 24     0.001007
# 29     0.001007
# Name: proportion, dtype: float64
#
# Column: number_inpatient
# number_inpatient
# 0     66.683108
# 1     19.109550
# 2      7.348278
# 3      3.292633
# 4      1.584410
# 5      0.796231
# 6      0.477135
# 7      0.263733
# 8      0.145959
# 9      0.109721
# 10     0.059390
# 11     0.049324
# 12     0.032212
# 13     0.018119
# 14     0.010066
# 15     0.009060
# 16     0.006040
# 19     0.002013
# 17     0.001007
# 21     0.001007
# 18     0.001007
# Name: proportion, dtype: float64
#
# Column: diag_1
# diag_1
# 428    6.708416
# 414    6.594646
# 786    4.042367
# 410    3.471502
# 486    3.406059
#          ...
# 833    0.001007
# 391    0.001007
# 690    0.001007
# 10     0.001007
# V51    0.001007
# Name: proportion, Length: 715, dtype: float64
#
# Column: diag_2
# diag_2
# 276    6.656430
# 428    6.525099
# 250    6.112924
# 427    4.942063
# 401    3.760090
#          ...
# 123    0.001010
# 884    0.001010
# V60    0.001010
# 843    0.001010
# 927    0.001010
# Name: proportion, Length: 747, dtype: float64
#
# Column: diag_3
# diag_3
# 250    11.709081
# 401     8.415710
# 276     5.058004
# 428     4.505535
# 427     3.865242
#          ...
# 14      0.001021
# 750     0.001021
# 370     0.001021
# 671     0.001021
# 971     0.001021
# Name: proportion, Length: 786, dtype: float64
#
# Column: number_diagnoses
# number_diagnoses
# 9     48.126189
# 5     11.375739
# 8     10.427509
# 7     10.282556
# 6     10.052042
# 4      5.535367
# 3      2.842676
# 2      1.027752
# 1      0.220448
# 16     0.042278
# 13     0.016106
# 10     0.016106
# 11     0.011073
# 15     0.010066
# 12     0.008053
# 14     0.006040
# Name: proportion, dtype: float64
#
# Column: max_glu_serum
# max_glu_serum
# Norm    49.398292
# >200    27.542702
# >300    23.059006
# Name: proportion, dtype: float64
#
# Column: A1Cresult
# A1Cresult
# >8      48.336700
# Norm    29.238446
# >7      22.424854
# Name: proportion, dtype: float64
#
# Column: metformin
# metformin
# No        80.024763
# Steady    18.327411
# Up         1.070030
# Down       0.577796
# Name: proportion, dtype: float64
#
# Column: repaglinide
# repaglinide
# No        98.471961
# Steady     1.377047
# Up         0.107708
# Down       0.043284
# Name: proportion, dtype: float64
#
# Column: nateglinide
# nateglinide
# No        99.306443
# Steady     0.658325
# Up         0.024159
# Down       0.011073
# Name: proportion, dtype: float64
#
# Column: chlorpropamide
# chlorpropamide
# No        99.914438
# Steady     0.078516
# Up         0.006040
# Down       0.001007
# Name: proportion, dtype: float64
#
# Column: glimepiride
# glimepiride
# No        94.844126
# Steady     4.639481
# Up         0.324130
# Down       0.192263
# Name: proportion, dtype: float64
#
# Column: acetohexamide
# acetohexamide
# No        99.998993
# Steady     0.001007
# Name: proportion, dtype: float64
#
# Column: glipizide
# glipizide
# No        87.386127
# Steady    11.293196
# Up         0.769053
# Down       0.551624
# Name: proportion, dtype: float64
#
# Column: glyburide
# glyburide
# No        89.407407
# Steady     9.222592
# Up         0.806297
# Down       0.563704
# Name: proportion, dtype: float64
#
# Column: tolbutamide
# tolbutamide
# No        99.978861
# Steady     0.021139
# Name: proportion, dtype: float64
#
# Column: pioglitazone
# pioglitazone
# No        92.697019
# Steady     6.953686
# Up         0.231521
# Down       0.117774
# Name: proportion, dtype: float64
#
# Column: rosiglitazone
# rosiglitazone
# No        93.654309
# Steady     6.087998
# Up         0.172131
# Down       0.085562
# Name: proportion, dtype: float64
#
# Column: acarbose
# acarbose
# No        99.692983
# Steady     0.293931
# Up         0.010066
# Down       0.003020
# Name: proportion, dtype: float64
#
# Column: miglitol
# miglitol
# No        99.961749
# Steady     0.031205
# Down       0.005033
# Up         0.002013
# Name: proportion, dtype: float64
#
# Column: troglitazone
# troglitazone
# No        99.99698
# Steady     0.00302
# Name: proportion, dtype: float64
#
# Column: tolazamide
# tolazamide
# No        99.960742
# Steady     0.038251
# Up         0.001007
# Name: proportion, dtype: float64
#
# Column: examide
# examide
# No    100.0
# Name: proportion, dtype: float64
#
# Column: citoglipton
# citoglipton
# No    100.0
# Name: proportion, dtype: float64
#
# Column: insulin
# insulin
# No        46.685725
# Steady    30.267860
# Down      11.986753
# Up        11.059662
# Name: proportion, dtype: float64
#
# Column: glyburide-metformin
# glyburide-metformin
# No        99.297384
# Steady     0.688524
# Up         0.008053
# Down       0.006040
# Name: proportion, dtype: float64
#
# Column: glipizide-metformin
# glipizide-metformin
# No        99.986914
# Steady     0.013086
# Name: proportion, dtype: float64
#
# Column: glimepiride-pioglitazone
# glimepiride-pioglitazone
# No        99.998993
# Steady     0.001007
# Name: proportion, dtype: float64
#
# Column: metformin-rosiglitazone
# metformin-rosiglitazone
# No        99.997987
# Steady     0.002013
# Name: proportion, dtype: float64
#
# Column: metformin-pioglitazone
# metformin-pioglitazone
# No        99.998993
# Steady     0.001007
# Name: proportion, dtype: float64
#
# Column: change
# change
# No    53.572974
# Ch    46.427026
# Name: proportion, dtype: float64
#
# Column: diabetesMed
# diabetesMed
# Yes    77.226377
# No     22.773623
# Name: proportion, dtype: float64
#
# Column: readmitted
# readmitted
# NO     52.874385
# >30    35.736791
# <30    11.388825
# Name: proportion, dtype: float64
#
# Column: age_numeric
# age_numeric
# 75    25.498525
# 65    22.204886
# 55    17.172825
# 85    16.542685
# 45     9.670535
# 35     3.788893
# 95     2.606122
# 25     1.659906
# 15     0.694563
# 5      0.161058
# Name: proportion, dtype: float64
#
# Column: diag_1_category
# diag_1_category
# other          40.720534
# circulatory    29.780659
# respiratory     9.984599
# digestive       9.131997
# diabetes        8.718279
# external        1.643800
# missing         0.020132
# Name: proportion, dtype: float64
#
# Column: diag_2_category
# diag_2_category
# other          39.710901
# circulatory    30.889947
# diabetes       12.789024
# respiratory     9.813475
# digestive       3.907673
# external        2.530626
# missing         0.358354
# Name: proportion, dtype: float64
#
# Column: diag_3_category
# diag_3_category
# other          36.992038
# circulatory    29.438410
# diabetes       17.091290
# respiratory     6.467491
# external        5.052193
# digestive       3.530193
# missing         1.428384
# Name: proportion, dtype: float64
#
# Column: readmission_binary
# readmission_binary
# 0    52.874385
# 1    47.125615
# Name: proportion, dtype: float64
#
# Column: n_meds_changed
# n_meds_changed
# 1    46.334417
# 0    22.773623
# 2    21.737817
# 3     7.757970
# 4     1.332756
# 5     0.058384
# 6     0.005033
# Name: proportion, dtype: float64
#
# Column: any_med_changed
# any_med_changed
# 1    77.226377
# 0    22.773623
# Name: proportion, dtype: float64
#
# Column: n_meds_increased
# n_meds_increased
# 0    86.022166
# 1    13.397018
# 2     0.547598
# 3     0.033218
# Name: proportion, dtype: float64
#
# Column: complexity_score
# complexity_score
# 2.870000    0.176157
# 3.000000    0.155018
# 2.620000    0.150992
# 2.750000    0.147972
# 2.670000    0.146966
#               ...
# 3.828889    0.001007
# 3.934444    0.001007
# 5.967778    0.001007
# 7.733333    0.001007
# 7.567778    0.001007
# Name: proportion, Length: 8560, dtype: float64

# %%
df_patient.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 99343 entries, 0 to 101765
# Data columns (total 59 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   encounter_id              99343 non-null  int64
#  1   patient_nbr               99343 non-null  int64
#  2   race                      97109 non-null  str
#  3   gender                    99343 non-null  str
#  4   age                       99343 non-null  str
#  5   weight                    3125 non-null   str
#  6   admission_type_id         99343 non-null  int64
#  7   discharge_disposition_id  99343 non-null  int64
#  8   admission_source_id       99343 non-null  int64
#  9   time_in_hospital          99343 non-null  int64
#  10  payer_code                59945 non-null  str
#  11  medical_specialty         50727 non-null  str
#  12  num_lab_procedures        99343 non-null  int64
#  13  num_procedures            99343 non-null  int64
#  14  num_medications           99343 non-null  int64
#  15  number_outpatient         99343 non-null  int64
#  16  number_emergency          99343 non-null  int64
#  17  number_inpatient          99343 non-null  int64
#  18  diag_1                    99323 non-null  str
#  19  diag_2                    98987 non-null  str
#  20  diag_3                    97924 non-null  str
#  21  number_diagnoses          99343 non-null  int64
#  22  max_glu_serum             5152 non-null   str
#  23  A1Cresult                 16834 non-null  str
#  24  metformin                 99343 non-null  str
#  25  repaglinide               99343 non-null  str
#  26  nateglinide               99343 non-null  str
#  27  chlorpropamide            99343 non-null  str
#  28  glimepiride               99343 non-null  str
#  29  acetohexamide             99343 non-null  str
#  30  glipizide                 99343 non-null  str
#  31  glyburide                 99343 non-null  str
#  32  tolbutamide               99343 non-null  str
#  33  pioglitazone              99343 non-null  str
#  34  rosiglitazone             99343 non-null  str
#  35  acarbose                  99343 non-null  str
#  36  miglitol                  99343 non-null  str
#  37  troglitazone              99343 non-null  str
#  38  tolazamide                99343 non-null  str
#  39  examide                   99343 non-null  str
#  40  citoglipton               99343 non-null  str
#  41  insulin                   99343 non-null  str
#  42  glyburide-metformin       99343 non-null  str
#  43  glipizide-metformin       99343 non-null  str
#  44  glimepiride-pioglitazone  99343 non-null  str
#  45  metformin-rosiglitazone   99343 non-null  str
#  46  metformin-pioglitazone    99343 non-null  str
#  47  change                    99343 non-null  str
#  48  diabetesMed               99343 non-null  str
#  49  readmitted                99343 non-null  str
#  50  age_numeric               99343 non-null  int64
#  51  diag_1_category           99343 non-null  str
#  52  diag_2_category           99343 non-null  str
#  53  diag_3_category           99343 non-null  str
#  54  readmission_binary        99343 non-null  int64
#  55  n_meds_changed            99343 non-null  int64
#  56  any_med_changed           99343 non-null  int64
#  57  n_meds_increased          99343 non-null  int64
#  58  complexity_score          99343 non-null  float64
# dtypes: float64(1), int64(18), str(40)
# memory usage: 45.5 MB

# %%
df_patient.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_patient.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... readmitted age_numeric  diag_1_category  \
# 0                 1  ...         NO           5         diabetes
# 1                 3  ...        >30          15            other
# 2                 2  ...         NO          25            other
# 3                 2  ...         NO          35            other
# 4                 1  ...         NO          45            other
#
#    diag_2_category  diag_3_category  readmission_binary  n_meds_changed  \
# 0          missing          missing                   0               0
# 1         diabetes            other                   1               1
# 2         diabetes         external                   0               1
# 3         diabetes      circulatory                   0               1
# 4            other         diabetes                   0               2
#
#    any_med_changed n_meds_increased complexity_score
# 0                0                0         0.981111
# 1                1                1         3.080000
# 2                1                0         2.570000
# 3                1                1         2.624444
# 4                1                0         1.975556
#
# [5 rows x 59 columns]

# %%
df_patient.to_csv("../data/processed/patient_encounters_2023_processed.csv")

# %%
#retinal
